# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.preprocessing import MinMaxScaler, StandardScaler, PolynomialFeatures

# %% [markdown]
# ### 1.1 Выведите аналитическое решение задачи регрессии. Используйте векторную форму уравнения.
#
# - Задача регрессии - задача, в которой нужно предсказать значение переменной (y), на основе одной или нескольких переменных (X)
# - Дано: Xi - матрица признаков и соответствующее значение yi

# %% [markdown]
# - Векторная форма уравнения: y = Xw + e
#     - y - Вектор значений
#     - X - Матрица признаков
#     - w - Вектор коэффициентов
#     - e - Вектор ошибок

# %% [markdown]
# - Цель:
#   - Найти вектор коэффициентов w, который минимизирует сумму квадратов ошибок.
#   - Ошибки определяются как разность между значениями y и предсказанными значениями Xw

# %% [markdown]
# - Минимизация ошибки: Q(X, w) = (Xw - y)² -> min
# - Метод Наименьших Квадратов (МНК)

# %% [markdown]
# - Для того, чтобы найти минимальное w, нужно раскрыть уравнение
#     (Xw - y)ᵀ(Xw - y) =
#     (Xᵀwᵀ - yᵀ)(Xw - y) =
#     XᵀwᵀXw - Xᵀwᵀy - yᵀXw + yᵀy =
#     yᵀy - 2yᵀXw + wᵀXᵀXw
# - Затем нужно взять производную и приравнять значение к 0, чтобы найти минимальное
#     -2Xᵀy + 2XᵀXw = 0
#     2XᵀXw = 2Xᵀy
#     w = Xᵀy / XᵀX
# - Итого:
#     w = (XᵀX)⁻¹ * Xᵀy
# - Это псевдообратная матрица

# %% [markdown]
# ### 1.2 Что меняется в решении при добавлении регуляризаций L1 и L2 к функции потерь?

# %% [markdown]
# - Регуляризация — это техника для предотвращения переобучения модели. Переобучение происходит, когда модель слишком хорошо подстраивается под обучающие данные, включая шум и выбросы, что приводит к плохой обобщающей способности на новых данных.
# - Кратко: Регуляризации - это штраф за большие веса.

# %% [markdown]
# - L1 Регуляризация (Lasso)
#     - Добавляет к функции потерь сумму абсолютных значений коэффициентов модели, умноженную на некоторый коэффициент регуляризации (λ)
#     - Loss = Loss(original) + λ∑∣wᵢ∣
#     -  Q(X, w) = (Xw - y)² + λ∑∣wᵢ∣
#     -  где, wᵢ - коэф модели, λ - параметр регуляризации.

# %% [markdown]
# - Свойства L1 Регуляризации:
#     - Сжатие коэффициентов: Некоторые коэф станут равны нулю. Происходит отбор наиболее важных признаков
#     - Непрерывность: Создает ромбовидный контур уровня, что приводит к тому, что решение может находиться на краю контура, где некоторые коэф будут равны нулю

# %% [markdown]
# - L2 Регуляризация (Ridge)
#     - Добавляет к функции потерь сумму квадратов значений коэффициентов модели, умноженнную на коэффициент регуляризации (λ)
#     - Loss = Loss(original) + λ∑wᵢ²
#     - Q(X, w) = (Xw - y)² + λ∑wᵢ²

# %% [markdown]
# - Свойства L2 Регуляризации:
#     - Сглаживание коэффициентов: L2 регуляризация не приводит к обнулению коэф, а скорее уменьшает их значение. Это в силу круглой формы контуров уровня
#     - Устойчивоть: L2 регуляризация помогает избежать переобучения, особенно когда  много признаков, которые могут быть коррелированы. Она "размазывает" влияние всех признаков, что делает модель более устойчивой к шуму.
#     - ∑∣wᵢ∣ = ||wᵢ||

# %% [markdown]
# ### 1.3 Объясните, почему регуляризация L1 часто используется для выбора признаков. Почему после подгонки модели многие веса равны 0?

# %% [markdown]
# - Это следует из свойств регуляризации, потому что просиходит отбор наиболее важных признаков, другие зануляются.

# %% [markdown]
# - Когда мы минимизируем функцию потерь, L1 регуляризация создает "ромбовидный" контур уровня. Это означает, что оптимальное решение может находиться на границе этого контура, где некоторые коэффициенты равны нулю.

# %% [markdown]
# ### 1.4 Объясните, как можно использовать те же модели (линейную регрессию, гребневую и т. д.), но сделать возможным подгонку нелинейных зависимостей.

# %% [markdown]
# - Полиномиальные признаки (использовать к примеру не только x, а еще x², x³)
# - Преобразование признаков (к примеру есть признак x, можно добавить log(x) или sin(x) в качестве новых признаков)
# - Взаимодействие признаков (есть признаки x1, x2, можно добавить признак x1 * x2)

# %%
df = pd.read_json('data/train2.json')

# %%
df.shape
# Out:
# (49352, 15)

# %%
df.head()
# Out:
#     bathrooms  bedrooms                       building_id  \
# 4         1.0         1  8579a0b0d54db803821a35a4a615e97a
# 6         1.0         2  b8e75fc949a6cd8225b455648a951712
# 9         1.0         2  cd759a988b8f23924b5a2058d5ab2b49
# 10        1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 15        1.0         0  bfb9405149bfff42a92980b594c28234
#
#                 created                                        description  \
# 4   2016-06-16 05:55:27  Spacious 1 Bedroom 1 Bathroom in Williamsburg!...
# 6   2016-06-01 05:44:33  BRAND NEW GUT RENOVATED TRUE 2 BEDROOMFind you...
# 9   2016-06-14 15:19:59  **FLEX 2 BEDROOM WITH FULL PRESSURIZED WALL**L...
# 10  2016-06-24 07:54:24  A Brand New 3 Bedroom 1.5 bath ApartmentEnjoy ...
# 15  2016-06-28 03:50:23  Over-sized Studio w abundant closets. Availabl...
#
#         display_address                                           features  \
# 4   145 Borinquen Place  [Dining Room, Pre-War, Laundry in Building, Di...
# ...

# %%
lower_bound = df['price'].quantile(0.01)
upper_bound = df['price'].quantile(0.99)

df = df[(df['price'] > lower_bound) & (df['price'] < upper_bound)]
df.shape
# Out:
# (48343, 15)

# %%
def clean_features(features):
    result = [feature.replace('[', '').replace(']', '')\
              .replace("'", '').replace('"', '').replace(' ', '') for feature in features]
    return result

# %%
df['features'] = df['features'].apply(clean_features)

# %%
df.head()
# Out:
#     bathrooms  bedrooms                       building_id  \
# 4         1.0         1  8579a0b0d54db803821a35a4a615e97a
# 6         1.0         2  b8e75fc949a6cd8225b455648a951712
# 9         1.0         2  cd759a988b8f23924b5a2058d5ab2b49
# 10        1.5         3  53a5b119ba8f7b61d4e010512e0dfc85
# 15        1.0         0  bfb9405149bfff42a92980b594c28234
#
#                 created                                        description  \
# 4   2016-06-16 05:55:27  Spacious 1 Bedroom 1 Bathroom in Williamsburg!...
# 6   2016-06-01 05:44:33  BRAND NEW GUT RENOVATED TRUE 2 BEDROOMFind you...
# 9   2016-06-14 15:19:59  **FLEX 2 BEDROOM WITH FULL PRESSURIZED WALL**L...
# 10  2016-06-24 07:54:24  A Brand New 3 Bedroom 1.5 bath ApartmentEnjoy ...
# 15  2016-06-28 03:50:23  Over-sized Studio w abundant closets. Availabl...
#
#         display_address                                           features  \
# 4   145 Borinquen Place  [DiningRoom, Pre-War, LaundryinBuilding, Dishw...
# ...

# %%
sns.histplot(data=df['price'], bins=50)
plt.title('Histogram')
plt.show()

# %%
result_list = []

for index, row in df.iterrows():
    result_list.extend(row['features'])

result_list = [item.strip() for item in result_list]

# %%
result_list[:5]
# Out:
# ['DiningRoom', 'Pre-War', 'LaundryinBuilding', 'Dishwasher', 'HardwoodFloors']

# %%
len(set(result_list))
# Out:
# 1528

# %%
count_features = Counter(result_list)

# %%
top20_count = count_features.most_common(20)

# %%
top20_count
# Out:
# [('Elevator', 25375),
#  ('HardwoodFloors', 23146),
#  ('CatsAllowed', 23135),
#  ('DogsAllowed', 21652),
#  ('Doorman', 20479),
#  ('Dishwasher', 20081),
#  ('NoFee', 17793),
#  ('LaundryinBuilding', 16082),
#  ('FitnessCenter', 12989),
#  ('Pre-War', 8971),
#  ('LaundryinUnit', 8437),
#  ('RoofDeck', 6417),
#  ('OutdoorSpace', 5132),
#  ('DiningRoom', 4890),
#  ('HighSpeedInternet', 4223),
#  ('Balcony', 2898),
#  ('SwimmingPool', 2643),
#  ('LaundryInBuilding', 2564),
#  ('NewConstruction', 2504),
#  ('Terrace', 2177)]

# %%
res = pd.DataFrame()

for feature in top20_count:
    res[feature[0]] = df['features'].apply(lambda x: 1 if feature[0] in x else 0)

# %%
res.head(1)
# Out:
#    Elevator  HardwoodFloors  CatsAllowed  DogsAllowed  Doorman  Dishwasher  \
# 4         0               1            1            1        0           1
#
#    NoFee  LaundryinBuilding  FitnessCenter  Pre-War  LaundryinUnit  RoofDeck  \
# 4      0                  1              0        1              0         0
#
#    OutdoorSpace  DiningRoom  HighSpeedInternet  Balcony  SwimmingPool  \
# 4             0           1                  0        0             0
#
#    LaundryInBuilding  NewConstruction  Terrace
# 4                  0                0        0

# %%
df.iloc[0]['features']
# Out:
# ['DiningRoom',
#  'Pre-War',
#  'LaundryinBuilding',
#  'Dishwasher',
#  'HardwoodFloors',
#  'DogsAllowed',
#  'CatsAllowed']

# %%
df_combined = pd.concat([df[['bathrooms', 'bedrooms', 'interest_level']], res], axis=1)

# %%
df_combined.head()
# Out:
#     bathrooms  bedrooms interest_level  Elevator  HardwoodFloors  CatsAllowed  \
# 4         1.0         1         medium         0               1            1
# 6         1.0         2            low         1               1            0
# 9         1.0         2         medium         1               1            0
# 10        1.5         3         medium         0               0            0
# 15        1.0         0            low         1               0            0
#
#     DogsAllowed  Doorman  Dishwasher  NoFee  ...  LaundryinUnit  RoofDeck  \
# 4             1        0           1      0  ...              0         0
# 6             0        1           1      1  ...              0         0
# 9             0        1           1      0  ...              1         0
# 10            0        0           0      0  ...              0         0
# 15            0        1           0      0  ...              0         0
#
# ...

# %%
df_combined
# Out:
#         bathrooms  bedrooms interest_level  Elevator  HardwoodFloors  \
# 4             1.0         1         medium         0               1
# 6             1.0         2            low         1               1
# 9             1.0         2         medium         1               1
# 10            1.5         3         medium         0               0
# 15            1.0         0            low         1               0
# ...           ...       ...            ...       ...             ...
# 124000        1.0         3            low         1               1
# 124002        1.0         2         medium         1               0
# 124004        1.0         1         medium         1               1
# 124008        1.0         2         medium         0               0
# 124009        1.0         3           high         1               1
#
#         CatsAllowed  DogsAllowed  Doorman  Dishwasher  NoFee  ...  \
# 4                 1            1        0           1      0  ...
# ...

# %%
df_combined['interest_level'] = df_combined['interest_level'].replace({'low': 1, 'medium': 2, 'high': 3})

# %%
df_combined
# Out:
#         bathrooms  bedrooms  interest_level  Elevator  HardwoodFloors  \
# 4             1.0         1               2         0               1
# 6             1.0         2               1         1               1
# 9             1.0         2               2         1               1
# 10            1.5         3               2         0               0
# 15            1.0         0               1         1               0
# ...           ...       ...             ...       ...             ...
# 124000        1.0         3               1         1               1
# 124002        1.0         2               2         1               0
# 124004        1.0         1               2         1               1
# 124008        1.0         2               2         0               0
# 124009        1.0         3               3         1               1
#
#         CatsAllowed  DogsAllowed  Doorman  Dishwasher  NoFee  ...  \
# ...

# %%
target = df['price']
df = df_combined

# %%
target.shape
# Out:
# (48343,)

# %%
df.shape
# Out:
# (48343, 23)

# %%
X_train, X_test, y_train, y_test = train_test_split(df, target, train_size=0.8)

# %%
class LinearRegressionSGD:
    def __init__(self, n_iter=1000, learning_rate=0.01):
        self.n_iter = n_iter
        self.learning_rate = learning_rate
        self.weights = None
        self.bias = None

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        for _ in range(self.n_iter):
            linear_output = np.dot(X, self.weights) + self.bias
            y_pred = linear_output

            # Вычисляем градиенты
            dw = (1 / n_samples) * np.dot(X.T, (y_pred - y))
            db = (1 / n_samples) * np.sum(y_pred - y)

            # Обновляем веса и смещение
            self.weights -= self.learning_rate * dw
            self.bias -= self.learning_rate * db

    def predict(self, X):
        linear_output = np.dot(X, self.weights) + self.bias
        return linear_output

# %%
class LinearRegressionGD:
    def __init__(self, learning_rate=0.1, n_iter=1000):
        self.learning_rate = learning_rate
        self.n_iter = n_iter
        self.weights = None
        self.bias = None

    def fit(self, X, y):
        n_samples, n_features = X.shape 
        self.weights = np.zeros(n_features)
        self.bias = 0

        for _ in range(self.n_iter):
            y_pred = np.dot(X, self.weights) + self.bias

            dw = (1 / n_samples) * np.dot(X.T, (y_pred - y))
            db = (1 / n_samples) * np.sum(y_pred - y)

            self.weights -= self.learning_rate * dw
            self.bias -= self.learning_rate * db

    def predict(self, X):
        return np.dot(X, self.weights) + self.bias

# %%
import numpy as np

class LinearRegressionAnalytic:
    def __init__(self):
        self.weights = None
        self.bias = None

    def fit(self, X, y):
        X_b = np.c_[np.ones((X.shape[0], 1)), X]  # Добавляем столбец единиц к X
        best_param = np.linalg.pinv(X_b.T.dot(X_b)).dot(X_b.T).dot(y)  # Используем псевдообратную матрицу
        self.weights = best_param[1:]  # Сохраняем веса
        self.bias = best_param[0]  # Сохраняем смещение

    def predict(self, X):
        X_b = np.c_[np.ones((X.shape[0], 1)), X]  # Добавляем столбец единиц к X
        return np.dot(X_b, np.r_[self.bias, self.weights])  # Используем объединение bias и weights

# %% [markdown]
# Коэффициент детерминации R2(R-квадрат)
# — это статистическая мера, которая показывает, насколько хорошо данные соответствуют модели регрессии. Он варьируется от 0 до 1, где 0 указывает на то, что модель не объясняет вариацию зависимой переменной, а 1 указывает на то, что модель полностью объясняет вариацию.
# - R2 = 1 − (SS(tot) / SS(res))
# - где:
#     - SS(res) — сумма квадратов остатков (разница между предсказанными и фактическими значениями),
#     - SS(tot) — общая сумма квадратов (разница между фактическими значениями и их средним).

# %%
def r_squared(y_true, y_pred):
    y_true = np.array(y_true)
    y_pred = np.array(y_pred)
    
    ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
    ss_res = np.sum((y_true - y_pred) ** 2)
    r2 = 1 - (ss_res / ss_tot)
    return r2

# %%
result_MAE = pd.DataFrame(columns=['model', 'train', 'test'])
result_MSE = pd.DataFrame(columns=['model', 'train', 'test'])
result_R2 = pd.DataFrame(columns=['model', 'train', 'test'])

# %%
def init_train_predict_SGD():
    linearSGD = LinearRegressionSGD()
    linearSGD.fit(X_train, y_train)
    
    linearSGD_train_predict = linearSGD.predict(X_train)
    linearSGD_test_predict = linearSGD.predict(X_test)
    
    mae_train_SGD = mean_absolute_error(y_train, linearSGD_train_predict)
    mae_test_SGD = mean_absolute_error(y_test, linearSGD_test_predict)
    
    mse_train_SGD = np.sqrt(mean_squared_error(y_train, linearSGD_train_predict))
    mse_test_SGD = np.sqrt(mean_squared_error(y_test, linearSGD_test_predict))
    
    r2_train_SGD = r_squared(y_train, linearSGD_train_predict)
    r2_test_SGD = r_squared(y_test, linearSGD_test_predict)

    result_MAE.loc[len(result_MAE)] = ['modelSGD', mae_train_SGD, mae_test_SGD]
    result_MSE.loc[len(result_MSE)] = ['modelSGD', mse_train_SGD, mse_test_SGD]
    result_R2.loc[len(result_R2)] = ['modelSGD', r2_train_SGD, r2_test_SGD]

# %%
init_train_predict_SGD()

# %%
def init_train_predict_GD():
    linearGD = LinearRegressionGD()
    linearGD.fit(X_train, y_train)

    linearGD_train_predict = linearGD.predict(X_train)
    linearGD_test_predict = linearGD.predict(X_test)
    
    mae_train_GD = mean_absolute_error(y_train, linearGD_train_predict)
    mae_test_GD = mean_absolute_error(y_test, linearGD_test_predict)
    
    mse_train_GD = np.sqrt(mean_squared_error(y_train, linearGD_train_predict))
    mse_test_GD = np.sqrt(mean_squared_error(y_test, linearGD_test_predict))
    
    r2_train_GD = r_squared(y_train, linearGD_train_predict)
    r2_test_GD = r_squared(y_test, linearGD_test_predict)    

    result_MAE.loc[len(result_MAE)] = ['modelGD', mae_train_GD, mae_test_GD]
    result_MSE.loc[len(result_MSE)] = ['modelGD', mse_train_GD, mse_test_GD]
    result_R2.loc[len(result_R2)] = ['modelGD', r2_train_GD, r2_test_GD]

# %%
init_train_predict_GD()

# %%
def init_train_predict_Analytic():
    linearAnlytic = LinearRegressionAnalytic()
    linearAnlytic.fit(X_train, y_train)

    linearAnlytic_train_predict = linearAnlytic.predict(X_train)
    linearAnlytic_test_predict = linearAnlytic.predict(X_test)
    
    mae_train_Anlytic = mean_absolute_error(y_train, linearAnlytic_train_predict)
    mae_test_Anlytic = mean_absolute_error(y_test, linearAnlytic_test_predict)
    
    mse_train_Anlytic = np.sqrt(mean_squared_error(y_train, linearAnlytic_train_predict))
    mse_test_Anlytic = np.sqrt(mean_squared_error(y_test, linearAnlytic_test_predict))
    
    r2_train_Anlytic = r_squared(y_train, linearAnlytic_train_predict)
    r2_test_Anlytic = r_squared(y_test, linearAnlytic_test_predict)
    
    result_MAE.loc[len(result_MAE)] = ['modelAnlytic', mae_train_Anlytic, mae_test_Anlytic]
    result_MSE.loc[len(result_MSE)] = ['modelAnlytic', mse_train_Anlytic, mse_test_Anlytic]
    result_R2.loc[len(result_R2)] = ['modelAnlytic', r2_train_Anlytic, r2_test_Anlytic]

# %%
init_train_predict_Analytic()

# %%
def init_train_predict_Default():
    linearDefault = LinearRegression()
    linearDefault.fit(X_train, y_train)
  
    linearDefault_train_predict = linearDefault.predict(X_train)
    linearDefault_test_predict = linearDefault.predict(X_test)
    
    mae_train_Default = mean_absolute_error(y_train, linearDefault_train_predict)
    mae_test_Default = mean_absolute_error(y_test, linearDefault_test_predict)
    
    mse_train_Default = np.sqrt(mean_squared_error(y_train, linearDefault_train_predict))
    mse_test_Default = np.sqrt(mean_squared_error(y_test, linearDefault_test_predict))
    
    r2_train_Default = r_squared(y_train, linearDefault_train_predict)
    r2_test_Default = r_squared(y_test, linearDefault_test_predict)

    result_MAE.loc[len(result_MAE)] = ['modelDefault', mae_train_Default, mae_test_Default]
    result_MSE.loc[len(result_MSE)] = ['modelDefault', mse_train_Default, mse_test_Default]
    result_R2.loc[len(result_R2)] = ['modelDefault', r2_train_Default, r2_test_Default]

# %%
init_train_predict_Default()

# %%
result_MAE
# Out:
#           model       train        test
# 0      modelSGD  685.781892  691.163394
# 1       modelGD  686.192905  691.382679
# 2  modelAnlytic  686.298000  691.473165
# 3  modelDefault  686.298000  691.473165

# %%
result_MSE
# Out:
#           model        train         test
# 0      modelSGD  1001.507985  1022.125160
# 1       modelGD   992.414073  1012.883779
# 2  modelAnlytic   992.405090  1012.842815
# 3  modelDefault   992.405090  1012.842815

# %%
result_R2
# Out:
#           model     train      test
# 0      modelSGD  0.597544  0.598400
# 1       modelGD  0.604819  0.605629
# 2  modelAnlytic  0.604827  0.605661
# 3  modelDefault  0.604827  0.605661

# %%
class CustomRidge:
    def __init__(self, alpha=1.0):
        self.alpha = alpha # Параметр регуляризации
        self.coef_ = None # Коэф модели
        self.intercept_ = None # Свободный член

    def fit(self, X, y):
        X_b = np.c_[np.ones((X.shape[0], 1)), X] # Добавляем столбец единиц к X, чтобы учесть смещение
        I = np.eye(X_b.shape[1]) # Создаем единичную матрицу
        I[0, 0] = 0  # Не регуляризуем свободный член
        # По формуле для регрессии Риджа, вычисляем коэффициенты модели
        self.coef_ = np.linalg.inv(X_b.T.dot(X_b) + self.alpha * I).dot(X_b.T).dot(y)
        self.intercept_ = self.coef_[0] # Сохраняем значение свободного члена
        self.coef_ = self.coef_[1:] # Сохраняем коэф без смещения

    def predict(self, X):
        return np.dot(X, self.coef_) + self.intercept_

# %%
class CustomLasso:
    def __init__(self, alpha=1.0, lr=0.1, n_iter=100):
        self.alpha = alpha
        self.lr = lr # Learning rate, скорость обучения
        self.n_iter = n_iter # Колчиество итераций
        self.coef_ = None
        self.intercept_ = None

    def fit(self, X, y):
        m, n = X.shape
        self.coef_ = np.zeros(n)
        self.intercept_ = 0
        
        for _ in range(self.n_iter):
            y_pred = np.dot(X, self.coef_) + self.intercept_
            errors = y_pred - y
            
            # Считаем градиенты
            d_coef = np.dot(X.T, errors) / m + self.alpha * np.sign(self.coef_)
            # np.dot(X.T * errors) / m - градиент потерь
            # self.alpha * np.sign(self.coef_) - штраф
            d_intercept = np.mean(errors)

            self.coef_ -= self.lr * d_coef
            self.intercept_ -= self.lr * d_intercept
            
    def predict(self, X):
        return np.dot(X, self.coef_) + self.intercept_

# %%
class CustomElasticNet:
    def __init__(self, alpha=1.0, l1_ratio=0.5, lr=0.01, n_iter=1000):
        self.alpha = alpha
        self.l1_ratio = l1_ratio
        self.lr = lr
        self.n_iter = n_iter
        self.coef_ = None
        self.intercept_ = None

    def fit(self, X, y):
        m, n = X.shape
        self.coef_ = np.zeros(n)
        self.intercept_ = 0

        for _ in range(self.n_iter):
            y_pred = np.dot(X, self.coef_) + self.intercept_
            errors = y_pred - y
            # Градиенты
            l1_term = self.alpha * self.l1_ratio * np.sign(self.coef_)
            l2_term = self.alpha * (1 - self.l1_ratio) * self.coef_
            d_coef = np.dot(X.T, errors) / m + l1_term + l2_term
            d_intercept = np.mean(errors)

            self.coef_ -= self.lr * d_coef
            self.intercept_ -= self.lr * d_intercept

    def predict(self, X):
        return np.dot(X, self.coef_) + self.intercept_

# %%
def init_train_predict_Ridge():
    linearRidge = CustomRidge()
    linearRidge.fit(X_train, y_train)
  
    linearRidge_train_predict = linearRidge.predict(X_train)
    linearRidge_test_predict = linearRidge.predict(X_test)
    
    mae_train_Ridge = mean_absolute_error(y_train, linearRidge_train_predict)
    mae_test_Ridge = mean_absolute_error(y_test, linearRidge_test_predict)
    
    mse_train_Ridge = np.sqrt(mean_squared_error(y_train, linearRidge_train_predict))
    mse_test_Ridge = np.sqrt(mean_squared_error(y_test, linearRidge_test_predict))
    
    r2_train_Ridge = r_squared(y_train, linearRidge_train_predict)
    r2_test_Ridge = r_squared(y_test, linearRidge_test_predict)

    result_MAE.loc[len(result_MAE)] = ['modelRidge', mae_train_Ridge, mae_test_Ridge]
    result_MSE.loc[len(result_MSE)] = ['modelRidge', mse_train_Ridge, mse_test_Ridge]
    result_R2.loc[len(result_R2)] = ['modelRidge', r2_train_Ridge, r2_test_Ridge]

# %%
init_train_predict_Ridge()

# %%
def init_train_predict_Lasso():
    modelLasso = CustomLasso()
    modelLasso.fit(X_train, y_train)

    lasso_train_predict = modelLasso.predict(X_train)
    lasso_test_predict = modelLasso.predict(X_test)

    mae_train_Lasso = mean_absolute_error(y_train, lasso_train_predict)
    mse_train_Lasso = np.sqrt(mean_squared_error(y_train, lasso_train_predict))
    r2_train_Lasso = r_squared(y_train, lasso_train_predict)

    mae_test_Lasso = mean_absolute_error(y_test, lasso_test_predict)
    mse_test_Lasso = np.sqrt(mean_squared_error(y_test, lasso_test_predict))
    r2_test_Lasso = r_squared(y_test, lasso_test_predict)


    result_MAE.loc[len(result_MAE)] = ['modelLasso', mae_train_Lasso, mae_test_Lasso]
    result_MSE.loc[len(result_MSE)] = ['modelLasso', mse_train_Lasso, mse_test_Lasso]
    result_R2.loc[len(result_R2)] = ['modelLasso', r2_train_Lasso, r2_test_Lasso]

# %%
init_train_predict_Lasso()

# %%
def init_train_predict_ElasticNet():
        modelElasticNet = CustomElasticNet()
        modelElasticNet.fit(X_train, y_train)

        elasticnet_train_predict = modelElasticNet.predict(X_train)
        elasticnet_test_predict = modelElasticNet.predict(X_test)

        mae_train_ElasticNet = mean_absolute_error(y_train, elasticnet_train_predict)
        mse_train_ElasticNet = np.sqrt(mean_squared_error(y_train, elasticnet_train_predict))
        r2_train_ElasticNet = r_squared(y_train, elasticnet_train_predict)

        mae_test_ElasticNet = mean_absolute_error(y_test, elasticnet_test_predict)
        mse_test_ElasticNet = np.sqrt(mean_squared_error(y_test, elasticnet_test_predict))
        r2_test_ElasticNet = r_squared(y_test, elasticnet_test_predict)

        result_MAE.loc[len(result_MAE)] = ['modelElasticNet', mae_train_ElasticNet, mae_test_ElasticNet]
        result_MSE.loc[len(result_MSE)] = ['modelElasticNet', mse_train_ElasticNet, mse_test_ElasticNet]
        result_R2.loc[len(result_R2)] = ['modelElasticNet', r2_train_ElasticNet, r2_test_ElasticNet]

# %%
init_train_predict_ElasticNet()

# %%
result_MAE
# Out:
#              model       train        test
# 0         modelSGD  685.781892  691.163394
# 1          modelGD  686.192905  691.382679
# 2     modelAnlytic  686.298000  691.473165
# 3     modelDefault  686.298000  691.473165
# 4       modelRidge  686.294387  691.469444
# 5       modelLasso  685.572514  690.834147
# 6  modelElasticNet  752.360949  760.798047

# %%
result_MSE
# Out:
#              model        train         test
# 0         modelSGD  1001.507985  1022.125160
# 1          modelGD   992.414073  1012.883779
# 2     modelAnlytic   992.405090  1012.842815
# 3     modelDefault   992.405090  1012.842815
# 4       modelRidge   992.405097  1012.845912
# 5       modelLasso  1001.637716  1022.214552
# 6  modelElasticNet  1128.850385  1160.774434

# %%
result_R2
# Out:
#              model     train      test
# 0         modelSGD  0.597544  0.598400
# 1          modelGD  0.604819  0.605629
# 2     modelAnlytic  0.604827  0.605661
# 3     modelDefault  0.604827  0.605661
# 4       modelRidge  0.604827  0.605659
# 5       modelLasso  0.597440  0.598330
# 6  modelElasticNet  0.488692  0.482058

# %% [markdown]
# - Нормализация признаков — это процесс приведения всех признаков к одному масштабу. Это важно, потому что многие алгоритмы машинного обучения чувствительны к масштабу данных.
# Нормализация обязательна:
#     - Методы, основанные на расстояниях
#     - Методы, использующие градиентный спуск
#     - Методы с регуляризацией
# Нормализация не обязательна:
#     - Деревья решений и ансамбли на их основе:
#     - Методы, основанные на вероятностях:

# %% [markdown]
# # z = (x - u) / q

# %% [markdown]
# # X(scaled) = x - x(min) / x(max) - x(min)

# %%
def custom_minmax_scaler(X):
    X_min = np.min(X, axis=0)
    X_max = np.max(X, axis=0)
    X_scaled = (X - X_min) / (X_max - X_min)
    return X_scaled

# %%
X_scaled_custom = custom_minmax_scaler(X_train)

# %%
scaler = MinMaxScaler()
X_scaled_sklearn = scaler.fit_transform(X_train)

# %%
np.allclose(X_scaled_custom, X_scaled_sklearn) # Сравнение эквивалентности
# Out:
# True

# %%
def custom_standard_scaler(X):
    mean = np.mean(X, axis=0)
    std = np.std(X, axis=0)
    X_scaled = (X - mean) / std
    return X_scaled

# %%
X_scaled_custom = custom_standard_scaler(X_train)

# %%
scaler = StandardScaler()
X_scaled_sklearn = scaler.fit_transform(X_train)

# %%
np.allclose(X_scaled_custom, X_scaled_sklearn)
# Out:
# True

# %%
X_minmax_scaled_train = custom_minmax_scaler(X_train)
X_minmax_scaled_test = custom_minmax_scaler(X_test)

# %%
def init_train_predict_minmax_Default():
    linearDefault = LinearRegression()
    linearDefault.fit(X_minmax_scaled_train, y_train)
  
    linearDefault_train_predict = linearDefault.predict(X_minmax_scaled_train)
    linearDefault_test_predict = linearDefault.predict(X_minmax_scaled_test)
    
    mae_train_Default = mean_absolute_error(y_train, linearDefault_train_predict)
    mae_test_Default = mean_absolute_error(y_test, linearDefault_test_predict)
    
    mse_train_Default = np.sqrt(mean_squared_error(y_train, linearDefault_train_predict))
    mse_test_Default = np.sqrt(mean_squared_error(y_test, linearDefault_test_predict))
    
    r2_train_Default = r_squared(y_train, linearDefault_train_predict)
    r2_test_Default = r_squared(y_test, linearDefault_test_predict)

    result_MAE.loc[len(result_MAE)] = ['modelMinMaxScaledDefault', mae_train_Default, mae_test_Default]
    result_MSE.loc[len(result_MSE)] = ['modelMinMaxScaledDefault', mse_train_Default, mse_test_Default]
    result_R2.loc[len(result_R2)] = ['modelMinMaxScaledDefault', r2_train_Default, r2_test_Default]

# %%
def init_train_predict_minmax_Lasso():
    modelLasso = CustomLasso()
    modelLasso.fit(X_minmax_scaled_train, y_train)

    lasso_train_predict = modelLasso.predict(X_minmax_scaled_train)
    lasso_test_predict = modelLasso.predict(X_minmax_scaled_test)

    mae_train_Lasso = mean_absolute_error(y_train, lasso_train_predict)
    mse_train_Lasso = np.sqrt(mean_squared_error(y_train, lasso_train_predict))
    r2_train_Lasso = r_squared(y_train, lasso_train_predict)

    mae_test_Lasso = mean_absolute_error(y_test, lasso_test_predict)
    mse_test_Lasso = np.sqrt(mean_squared_error(y_test, lasso_test_predict))
    r2_test_Lasso = r_squared(y_test, lasso_test_predict)

    result_MAE.loc[len(result_MAE)] = ['modelMinMaxScaledLasso', mae_train_Lasso, mae_test_Lasso]
    result_MSE.loc[len(result_MSE)] = ['modelMinMaxScaledLasso', mse_train_Lasso, mse_test_Lasso]
    result_R2.loc[len(result_R2)] = ['modelMinMaxScaledLasso', r2_train_Lasso, r2_test_Lasso]

# %%
def init_train_predict_minmax_Ridge():
    linearRidge = CustomRidge()
    linearRidge.fit(X_minmax_scaled_train, y_train)
  
    linearRidge_train_predict = linearRidge.predict(X_minmax_scaled_train)
    linearRidge_test_predict = linearRidge.predict(X_minmax_scaled_test)
    
    mae_train_Ridge = mean_absolute_error(y_train, linearRidge_train_predict)
    mae_test_Ridge = mean_absolute_error(y_test, linearRidge_test_predict)
    
    mse_train_Ridge = np.sqrt(mean_squared_error(y_train, linearRidge_train_predict))
    mse_test_Ridge = np.sqrt(mean_squared_error(y_test, linearRidge_test_predict))
    
    r2_train_Ridge = r_squared(y_train, linearRidge_train_predict)
    r2_test_Ridge = r_squared(y_test, linearRidge_test_predict)

    result_MAE.loc[len(result_MAE)] = ['modelMinMaxScaledRidge', mae_train_Ridge, mae_test_Ridge]
    result_MSE.loc[len(result_MSE)] = ['modelMinMaxScaledRidge', mse_train_Ridge, mse_test_Ridge]
    result_R2.loc[len(result_R2)] = ['modelMinMaxScaledRidge', r2_train_Ridge, r2_test_Ridge]

# %%
def init_train_predict_minmax_ElasticNet():
    modelElasticNet = CustomElasticNet()
    modelElasticNet.fit(X_minmax_scaled_train, y_train)

    elasticnet_train_predict = modelElasticNet.predict(X_minmax_scaled_train)
    elasticnet_test_predict = modelElasticNet.predict(X_minmax_scaled_test)

    mae_train_ElasticNet = mean_absolute_error(y_train, elasticnet_train_predict)
    mse_train_ElasticNet = np.sqrt(mean_squared_error(y_train, elasticnet_train_predict))
    r2_train_ElasticNet = r_squared(y_train, elasticnet_train_predict)

    mae_test_ElasticNet = mean_absolute_error(y_test, elasticnet_test_predict)
    mse_test_ElasticNet = np.sqrt(mean_squared_error(y_test, elasticnet_test_predict))
    r2_test_ElasticNet = r_squared(y_test, elasticnet_test_predict)

    result_MAE.loc[len(result_MAE)] = ['modelMinMaxScaledElasticNet', mae_train_ElasticNet, mae_test_ElasticNet]
    result_MSE.loc[len(result_MSE)] = ['modelMinMaxScaledElasticNet', mse_train_ElasticNet, mse_test_ElasticNet]
    result_R2.loc[len(result_R2)] = ['modelMinMaxScaledElasticNet', r2_train_ElasticNet, r2_test_ElasticNet]

# %%
init_train_predict_minmax_Default()
init_train_predict_minmax_Ridge()
init_train_predict_minmax_Lasso()
init_train_predict_minmax_ElasticNet()

# %%
X_standart_scaled_train = custom_standard_scaler(X_train)
X_standart_scaled_test = custom_standard_scaler(X_test)

# %%
def init_train_predict_standart_Default():
    linearDefault = LinearRegression()
    linearDefault.fit(X_standart_scaled_train, y_train)
  
    linearDefault_train_predict = linearDefault.predict(X_standart_scaled_train)
    linearDefault_test_predict = linearDefault.predict(X_standart_scaled_test)
    
    mae_train_Default = mean_absolute_error(y_train, linearDefault_train_predict)
    mae_test_Default = mean_absolute_error(y_test, linearDefault_test_predict)
    
    mse_train_Default = np.sqrt(mean_squared_error(y_train, linearDefault_train_predict))
    mse_test_Default = np.sqrt(mean_squared_error(y_test, linearDefault_test_predict))
    
    r2_train_Default = r_squared(y_train, linearDefault_train_predict)
    r2_test_Default = r_squared(y_test, linearDefault_test_predict)

    result_MAE.loc[len(result_MAE)] = ['modelStandartScaledDefault', mae_train_Default, mae_test_Default]
    result_MSE.loc[len(result_MSE)] = ['modelStandartScaledDefault', mse_train_Default, mse_test_Default]
    result_R2.loc[len(result_R2)] = ['modelStandartScaledDefault', r2_train_Default, r2_test_Default]

# %%
def init_train_predict_standart_Lasso():
    modelLasso = CustomLasso()
    modelLasso.fit(X_standart_scaled_train, y_train)

    lasso_train_predict = modelLasso.predict(X_standart_scaled_train)
    lasso_test_predict = modelLasso.predict(X_standart_scaled_test)

    mae_train_Lasso = mean_absolute_error(y_train, lasso_train_predict)
    mse_train_Lasso = np.sqrt(mean_squared_error(y_train, lasso_train_predict))
    r2_train_Lasso = r_squared(y_train, lasso_train_predict)

    mae_test_Lasso = mean_absolute_error(y_test, lasso_test_predict)
    mse_test_Lasso = np.sqrt(mean_squared_error(y_test, lasso_test_predict))
    r2_test_Lasso = r_squared(y_test, lasso_test_predict)

    result_MAE.loc[len(result_MAE)] = ['modelStandartScaledLasso', mae_train_Lasso, mae_test_Lasso]
    result_MSE.loc[len(result_MSE)] = ['modelStandartScaledLasso', mse_train_Lasso, mse_test_Lasso]
    result_R2.loc[len(result_R2)] = ['modelStandartScaledLasso', r2_train_Lasso, r2_test_Lasso]

# %%
def init_train_predict_standart_Ridge():
    linearRidge = CustomRidge()
    linearRidge.fit(X_standart_scaled_train, y_train)
  
    linearRidge_train_predict = linearRidge.predict(X_standart_scaled_train)
    linearRidge_test_predict = linearRidge.predict(X_standart_scaled_test)
    
    mae_train_Ridge = mean_absolute_error(y_train, linearRidge_train_predict)
    mae_test_Ridge = mean_absolute_error(y_test, linearRidge_test_predict)
    
    mse_train_Ridge = np.sqrt(mean_squared_error(y_train, linearRidge_train_predict))
    mse_test_Ridge = np.sqrt(mean_squared_error(y_test, linearRidge_test_predict))
    
    r2_train_Ridge = r_squared(y_train, linearRidge_train_predict)
    r2_test_Ridge = r_squared(y_test, linearRidge_test_predict)

    result_MAE.loc[len(result_MAE)] = ['modelStandartScaledRidge', mae_train_Ridge, mae_test_Ridge]
    result_MSE.loc[len(result_MSE)] = ['modelStandartScaledRidge', mse_train_Ridge, mse_test_Ridge]
    result_R2.loc[len(result_R2)] = ['modelStandartScaledRidge', r2_train_Ridge, r2_test_Ridge]

# %%
def init_train_predict_standart_ElasticNet():
    modelElasticNet = CustomElasticNet()
    modelElasticNet.fit(X_standart_scaled_train, y_train)

    elasticnet_train_predict = modelElasticNet.predict(X_standart_scaled_train)
    elasticnet_test_predict = modelElasticNet.predict(X_standart_scaled_test)

    mae_train_ElasticNet = mean_absolute_error(y_train, elasticnet_train_predict)
    mse_train_ElasticNet = np.sqrt(mean_squared_error(y_train, elasticnet_train_predict))
    r2_train_ElasticNet = r_squared(y_train, elasticnet_train_predict)

    mae_test_ElasticNet = mean_absolute_error(y_test, elasticnet_test_predict)
    mse_test_ElasticNet = np.sqrt(mean_squared_error(y_test, elasticnet_test_predict))
    r2_test_ElasticNet = r_squared(y_test, elasticnet_test_predict)

    result_MAE.loc[len(result_MAE)] = ['modelStandartScaledElasticNet', mae_train_ElasticNet, mae_test_ElasticNet]
    result_MSE.loc[len(result_MSE)] = ['modelStandartScaledElasticNet', mse_train_ElasticNet, mse_test_ElasticNet]
    result_R2.loc[len(result_R2)] = ['modelStandartScaledElasticNet', r2_train_ElasticNet, r2_test_ElasticNet]

# %%
init_train_predict_standart_Default()
init_train_predict_standart_Ridge()
init_train_predict_standart_Lasso()
init_train_predict_standart_ElasticNet()

# %%
result_MAE
# Out:
#                             model        train         test
# 0                        modelSGD   685.781892   691.163394
# 1                         modelGD   686.192905   691.382679
# 2                    modelAnlytic   686.298000   691.473165
# 3                    modelDefault   686.298000   691.473165
# 4                      modelRidge   686.294387   691.469444
# 5                      modelLasso   685.572514   690.834147
# 6                 modelElasticNet   752.360949   760.798047
# 7        modelMinMaxScaledDefault   686.298000  2808.485853
# 8          modelMinMaxScaledRidge   686.446146  2763.874965
# 9          modelMinMaxScaledLasso   911.032938   939.801317
# 10    modelMinMaxScaledElasticNet  1029.630822  1039.778663
# 11     modelStandartScaledDefault   686.298000   689.268579
# 12       modelStandartScaledRidge   686.296860   689.267498
# 13       modelStandartScaledLasso   685.993123   688.982116
# 14  modelStandartScaledElasticNet   712.025958   715.181591

# %%
result_MSE
# Out:
#                             model        train         test
# 0                        modelSGD  1001.507985  1022.125160
# 1                         modelGD   992.414073  1012.883779
# 2                    modelAnlytic   992.405090  1012.842815
# 3                    modelDefault   992.405090  1012.842815
# 4                      modelRidge   992.405097  1012.845912
# 5                      modelLasso  1001.637716  1022.214552
# 6                 modelElasticNet  1128.850385  1160.774434
# 7        modelMinMaxScaledDefault   992.405090  3119.683236
# 8          modelMinMaxScaledRidge   992.452095  3071.243757
# 9          modelMinMaxScaledLasso  1318.525032  1323.932755
# 10    modelMinMaxScaledElasticNet  1459.551080  1489.451866
# 11     modelStandartScaledDefault   992.405090  1013.214816
# 12       modelStandartScaledRidge   992.405091  1013.215518
# 13       modelStandartScaledLasso   992.451114  1013.432069
# 14  modelStandartScaledElasticNet  1037.725410  1066.123584

# %%
result_R2
# Out:
#                             model     train      test
# 0                        modelSGD  0.597544  0.598400
# 1                         modelGD  0.604819  0.605629
# 2                    modelAnlytic  0.604827  0.605661
# 3                    modelDefault  0.604827  0.605661
# 4                      modelRidge  0.604827  0.605659
# 5                      modelLasso  0.597440  0.598330
# 6                 modelElasticNet  0.488692  0.482058
# 7        modelMinMaxScaledDefault  0.604827 -2.741161
# 8          modelMinMaxScaledRidge  0.604789 -2.625885
# 9          modelMinMaxScaledLasso  0.302432  0.326221
# 10    modelMinMaxScaledElasticNet  0.145232  0.147217
# 11     modelStandartScaledDefault  0.604827  0.605371
# 12       modelStandartScaledRidge  0.604827  0.605371
# 13       modelStandartScaledLasso  0.604790  0.605202
# 14  modelStandartScaledElasticNet  0.567910  0.563081

# %%
X, y = df[['bathrooms', 'bedrooms', 'interest_level']], target

# %%
poly = PolynomialFeatures(degree=10, include_bias=False)
X_poly = poly.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_poly, y, test_size=0.2, random_state=42)

# %%
def init_train_predict_polynomial_Default():
    linearDefault = LinearRegression()
    linearDefault.fit(X_train, y_train)
  
    linearDefault_train_predict = linearDefault.predict(X_train)
    linearDefault_test_predict = linearDefault.predict(X_test)
    
    mae_train_Default = mean_absolute_error(y_train, linearDefault_train_predict)
    mae_test_Default = mean_absolute_error(y_test, linearDefault_test_predict)
    
    mse_train_Default = np.sqrt(mean_squared_error(y_train, linearDefault_train_predict))
    mse_test_Default = np.sqrt(mean_squared_error(y_test, linearDefault_test_predict))
    
    r2_train_Default = r_squared(y_train, linearDefault_train_predict)
    r2_test_Default = r_squared(y_test, linearDefault_test_predict)

    result_MAE.loc[len(result_MAE)] = ['modelPolynomialDefault', mae_train_Default, mae_test_Default]
    result_MSE.loc[len(result_MSE)] = ['modelPolynomialDefault', mse_train_Default, mse_test_Default]
    result_R2.loc[len(result_R2)] = ['modelPolynomialDefault', r2_train_Default, r2_test_Default]

# %%
def init_train_predict_polynomial_Ridge():
    linearRidge = CustomRidge()
    linearRidge.fit(X_train, y_train)
  
    linearRidge_train_predict = linearRidge.predict(X_train)
    linearRidge_test_predict = linearRidge.predict(X_test)
    
    mae_train_Ridge = mean_absolute_error(y_train, linearRidge_train_predict)
    mae_test_Ridge = mean_absolute_error(y_test, linearRidge_test_predict)
    
    mse_train_Ridge = np.sqrt(mean_squared_error(y_train, linearRidge_train_predict))
    mse_test_Ridge = np.sqrt(mean_squared_error(y_test, linearRidge_test_predict))
    
    r2_train_Ridge = r_squared(y_train, linearRidge_train_predict)
    r2_test_Ridge = r_squared(y_test, linearRidge_test_predict)

    result_MAE.loc[len(result_MAE)] = ['modelPolynomialRidge', mae_train_Ridge, mae_test_Ridge]
    result_MSE.loc[len(result_MSE)] = ['modelPolynomialRidge', mse_train_Ridge, mse_test_Ridge]
    result_R2.loc[len(result_R2)] = ['modelPolynomialRidge', r2_train_Ridge, r2_test_Ridge]

# %%
def init_train_predict_polynomial_Lasso():
    global X_train, y_train
    X_train = np.nan_to_num(X_train, nan=0.0)  # Заменяем NaN на 0
    y_train = np.nan_to_num(y_train, nan=0.0)  # Заменяем NaN на 0
    modelLasso = CustomLasso()
    modelLasso.fit(X_train, y_train)

    lasso_train_predict = modelLasso.predict(X_train)
    lasso_test_predict = modelLasso.predict(X_test)

    mae_train_Lasso = mean_absolute_error(y_train, lasso_train_predict)
    mse_train_Lasso = np.sqrt(mean_squared_error(y_train, lasso_train_predict))
    r2_train_Lasso = r_squared(y_train, lasso_train_predict)

    mae_test_Lasso = mean_absolute_error(y_test, lasso_test_predict)
    mse_test_Lasso = np.sqrt(mean_squared_error(y_test, lasso_test_predict))
    r2_test_Lasso = r_squared(y_test, lasso_test_predict)

    result_MAE.loc[len(result_MAE)] = ['modelPolynomialLasso', mae_train_Lasso, mae_test_Lasso]
    result_MSE.loc[len(result_MSE)] = ['modelPolynomialLasso', mse_train_Lasso, mse_test_Lasso]
    result_R2.loc[len(result_R2)] = ['modelPolynomialLasso', r2_train_Lasso, r2_test_Lasso]

# %%
def init_train_predict_polynomial_ElasticNet():
    global X_train, y_train
    X_train = np.nan_to_num(X_train, nan=0.0)  # Заменяем NaN на 0
    y_train = np.nan_to_num(y_train, nan=0.0)  # Заменяем NaN на 0
    modelElasticNet = CustomElasticNet()
    modelElasticNet.fit(X_train, y_train)

    elasticnet_train_predict = modelElasticNet.predict(X_train)
    elasticnet_test_predict = modelElasticNet.predict(X_test)

    mae_train_ElasticNet = mean_absolute_error(y_train, elasticnet_train_predict)
    mse_train_ElasticNet = np.sqrt(mean_squared_error(y_train, elasticnet_train_predict))
    r2_train_ElasticNet = r_squared(y_train, elasticnet_train_predict)

    mae_test_ElasticNet = mean_absolute_error(y_test, elasticnet_test_predict)
    mse_test_ElasticNet = np.sqrt(mean_squared_error(y_test, elasticnet_test_predict))
    r2_test_ElasticNet = r_squared(y_test, elasticnet_test_predict)

    result_MAE.loc[len(result_MAE)] = ['modelPolynomialElasticNet', mae_train_ElasticNet, mae_test_ElasticNet]
    result_MSE.loc[len(result_MSE)] = ['modelPolynomialElasticNet', mse_train_ElasticNet, mse_test_ElasticNet]
    result_R2.loc[len(result_R2)] = ['modelPolynomialElasticNet', r2_train_ElasticNet, r2_test_ElasticNet]

# %%
init_train_predict_polynomial_Default()
init_train_predict_polynomial_Ridge()

# %%
result_MAE
# Out:
#                             model        train          test
# 0                        modelSGD   685.781892  6.911634e+02
# 1                         modelGD   686.192905  6.913827e+02
# 2                    modelAnlytic   686.298000  6.914732e+02
# 3                    modelDefault   686.298000  6.914732e+02
# 4                      modelRidge   686.294387  6.914694e+02
# 5                      modelLasso   685.572514  6.908341e+02
# 6                 modelElasticNet   752.360949  7.607980e+02
# 7        modelMinMaxScaledDefault   686.298000  2.808486e+03
# 8          modelMinMaxScaledRidge   686.446146  2.763875e+03
# 9          modelMinMaxScaledLasso   911.032938  9.398013e+02
# 10    modelMinMaxScaledElasticNet  1029.630822  1.039779e+03
# 11     modelStandartScaledDefault   686.298000  6.892686e+02
# 12       modelStandartScaledRidge   686.296860  6.892675e+02
# 13       modelStandartScaledLasso   685.993123  6.889821e+02
# ...

# %%
result_MSE
# Out:
#                             model        train          test
# 0                        modelSGD  1001.507985  1.022125e+03
# 1                         modelGD   992.414073  1.012884e+03
# 2                    modelAnlytic   992.405090  1.012843e+03
# 3                    modelDefault   992.405090  1.012843e+03
# 4                      modelRidge   992.405097  1.012846e+03
# 5                      modelLasso  1001.637716  1.022215e+03
# 6                 modelElasticNet  1128.850385  1.160774e+03
# 7        modelMinMaxScaledDefault   992.405090  3.119683e+03
# 8          modelMinMaxScaledRidge   992.452095  3.071244e+03
# 9          modelMinMaxScaledLasso  1318.525032  1.323933e+03
# 10    modelMinMaxScaledElasticNet  1459.551080  1.489452e+03
# 11     modelStandartScaledDefault   992.405090  1.013215e+03
# 12       modelStandartScaledRidge   992.405091  1.013216e+03
# 13       modelStandartScaledLasso   992.451114  1.013432e+03
# ...

# %%
result_R2
# Out:
#                             model     train          test
# 0                        modelSGD  0.597544  5.984001e-01
# 1                         modelGD  0.604819  6.056293e-01
# 2                    modelAnlytic  0.604827  6.056612e-01
# 3                    modelDefault  0.604827  6.056612e-01
# 4                      modelRidge  0.604827  6.056588e-01
# 5                      modelLasso  0.597440  5.983299e-01
# 6                 modelElasticNet  0.488692  4.820581e-01
# 7        modelMinMaxScaledDefault  0.604827 -2.741161e+00
# 8          modelMinMaxScaledRidge  0.604789 -2.625885e+00
# 9          modelMinMaxScaledLasso  0.302432  3.262213e-01
# 10    modelMinMaxScaledElasticNet  0.145232  1.472174e-01
# 11     modelStandartScaledDefault  0.604827  6.053715e-01
# 12       modelStandartScaledRidge  0.604827  6.053709e-01
# 13       modelStandartScaledLasso  0.604790  6.052022e-01
# 14  modelStandartScaledElasticNet  0.567910  5.630814e-01
# ...

# %%
mean_target = target.mean()
median_target = target.median()

# %%
mean_predictions_train = [mean_target] * len(X_train)
mean_predictions_test = [mean_target] * len(X_test)

# %%
median_predictions_train = [median_target] * len(X_train)
median_predictions_test = [median_target] * len(X_test)

# %%
mae_train_mean = mean_absolute_error(y_train, mean_predictions_train)
mse_train_mean = np.sqrt(mean_squared_error(y_train, mean_predictions_train))
r2_train_mean = r_squared(y_train, mean_predictions_train)

mae_test_mean = mean_absolute_error(y_test, mean_predictions_test)
mse_test_mean = np.sqrt(mean_squared_error(y_test, mean_predictions_test))
r2_test_mean = r_squared(y_test, mean_predictions_test)

mae_median_train = mean_absolute_error(y_train, median_predictions_train)
mse_median_train = np.sqrt(mean_squared_error(y_train, median_predictions_train))
r2_median_train = r_squared(y_train, median_predictions_train)

mae_median_test = mean_absolute_error(y_test, median_predictions_test)
mse_median_test = np.sqrt(mean_squared_error(y_test, median_predictions_test))
r2_median_test = r_squared(y_test, median_predictions_test)

# %%
result_MAE.loc[len(result_MAE)] = ['modelMean', mae_train_mean, mae_test_mean]
result_MSE.loc[len(result_MSE)] = ['modelMean', mse_train_mean, mse_test_mean]
result_R2.loc[len(result_R2)] = ['modelMean', r2_train_mean, r2_test_mean]

result_MAE.loc[len(result_MAE)] = ['modelMedian', mae_median_train, mae_median_test]
result_MSE.loc[len(result_MSE)] = ['modelMedian', mse_median_train, mse_median_test]
result_R2.loc[len(result_R2)] = ['modelMedian', r2_median_train, r2_median_test]

# %%
result_MAE
# Out:
#                             model        train          test
# 0                        modelSGD   685.781892  6.911634e+02
# 1                         modelGD   686.192905  6.913827e+02
# 2                    modelAnlytic   686.298000  6.914732e+02
# 3                    modelDefault   686.298000  6.914732e+02
# 4                      modelRidge   686.294387  6.914694e+02
# 5                      modelLasso   685.572514  6.908341e+02
# 6                 modelElasticNet   752.360949  7.607980e+02
# 7        modelMinMaxScaledDefault   686.298000  2.808486e+03
# 8          modelMinMaxScaledRidge   686.446146  2.763875e+03
# 9          modelMinMaxScaledLasso   911.032938  9.398013e+02
# 10    modelMinMaxScaledElasticNet  1029.630822  1.039779e+03
# 11     modelStandartScaledDefault   686.298000  6.892686e+02
# 12       modelStandartScaledRidge   686.296860  6.892675e+02
# 13       modelStandartScaledLasso   685.993123  6.889821e+02
# ...

# %%
result_MSE
# Out:
#                             model        train          test
# 0                        modelSGD  1001.507985  1.022125e+03
# 1                         modelGD   992.414073  1.012884e+03
# 2                    modelAnlytic   992.405090  1.012843e+03
# 3                    modelDefault   992.405090  1.012843e+03
# 4                      modelRidge   992.405097  1.012846e+03
# 5                      modelLasso  1001.637716  1.022215e+03
# 6                 modelElasticNet  1128.850385  1.160774e+03
# 7        modelMinMaxScaledDefault   992.405090  3.119683e+03
# 8          modelMinMaxScaledRidge   992.452095  3.071244e+03
# 9          modelMinMaxScaledLasso  1318.525032  1.323933e+03
# 10    modelMinMaxScaledElasticNet  1459.551080  1.489452e+03
# 11     modelStandartScaledDefault   992.405090  1.013215e+03
# 12       modelStandartScaledRidge   992.405091  1.013216e+03
# 13       modelStandartScaledLasso   992.451114  1.013432e+03
# ...

# %%
result_R2
# Out:
#                             model     train          test
# 0                        modelSGD  0.597544  5.984001e-01
# 1                         modelGD  0.604819  6.056293e-01
# 2                    modelAnlytic  0.604827  6.056612e-01
# 3                    modelDefault  0.604827  6.056612e-01
# 4                      modelRidge  0.604827  6.056588e-01
# 5                      modelLasso  0.597440  5.983299e-01
# 6                 modelElasticNet  0.488692  4.820581e-01
# 7        modelMinMaxScaledDefault  0.604827 -2.741161e+00
# 8          modelMinMaxScaledRidge  0.604789 -2.625885e+00
# 9          modelMinMaxScaledLasso  0.302432  3.262213e-01
# 10    modelMinMaxScaledElasticNet  0.145232  1.472174e-01
# 11     modelStandartScaledDefault  0.604827  6.053715e-01
# 12       modelStandartScaledRidge  0.604827  6.053709e-01
# 13       modelStandartScaledLasso  0.604790  6.052022e-01
# 14  modelStandartScaledElasticNet  0.567910  5.630814e-01
# ...

# %% [markdown]
# ## Лучшие модели modelMinMaxScaledDefault modelMinMaxScaledLasso
